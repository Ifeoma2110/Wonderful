# %%
import pandas as pd
import numpy as np

# %%
Location = "datasets/DC_Properties.csv"
df = pd. read_csv(Location)
df.head()
# Out:
# C:\Users\ifeom\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (18,19,20,21,22,23,24,33,34,35,37,43,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 0           0       4          0      Warm Cool  Y        2.0      8      4
# 1           1       3          1      Warm Cool  Y        2.0     11      5
# 2           2       3          1  Hot Water Rad  Y        2.0      9      5
# 3           3       3          1  Hot Water Rad  Y        2.0      8      5
# 4           4       2          1      Warm Cool  Y        1.0     11      3
#
#       AYB  YR_RMDL  ...  LONGITUDE  ASSESSMENT_NBHD ASSESSMENT_SUBNBHD  \
# 0  1910.0   1988.0  ... -77.040832       Old City 2   040 D Old City 2
# 1  1898.0   2007.0  ... -77.040764       Old City 2   040 D Old City 2
# ...

# %%
df.corr()
# Out:
#               Unnamed: 0    BATHRM  HF_BATHRM  NUM_UNITS     ROOMS     BEDRM  \
# Unnamed: 0      1.000000 -0.378389  -0.358454  -0.051664 -0.585978 -0.598538
# BATHRM         -0.378389  1.000000   0.248759   0.403431  0.677751  0.655563
# HF_BATHRM      -0.358454  0.248759   1.000000  -0.151393  0.353825  0.375568
# NUM_UNITS      -0.051664  0.403431  -0.151393   1.000000  0.524724  0.330551
# ROOMS          -0.585978  0.677751   0.353825   0.524724  1.000000  0.841309
# BEDRM          -0.598538  0.655563   0.375568   0.330551  0.841309  1.000000
# AYB             0.438398 -0.039087  -0.009372  -0.104280 -0.219367 -0.242955
# YR_RMDL        -0.115391  0.239797   0.148483  -0.015551  0.161396  0.214655
# EYB            -0.133335  0.269444   0.235645  -0.069551  0.158847  0.168913
# STORIES        -0.043577  0.042349   0.033270   0.019268  0.039352  0.040859
# PRICE           0.033219 -0.006536  -0.013113  -0.000469 -0.038241 -0.043331
# ...

# %%
import statsmodels.formula.api as smf

# %%
result = smf.ols('PRICE ~ BATHRM + KITCHENS + BEDRM', data=df).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  PRICE   R-squared:                       0.284
# Model:                            OLS   Adj. R-squared:                  0.284
# Method:                 Least Squares   F-statistic:                     7672.
# Date:                Thu, 11 Jul 2019   Prob (F-statistic):               0.00
# Time:                        20:27:14   Log-Likelihood:            -8.4353e+05
# No. Observations:               57899   AIC:                         1.687e+06
# Df Residuals:                   57895   BIC:                         1.687e+06
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -2.807e+04   7127.304     -3.939      0.000    -4.2e+04   -1.41e+04
# ...

# %%
result = smf.ols('PRICE ~ ZIPCODE + KITCHENS + ROOMS + BEDRM + STORIES + BATHRM + HF_BATHRM + NUM_UNITS + FIREPLACES ', data=df).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  PRICE   R-squared:                       0.411
# Model:                            OLS   Adj. R-squared:                  0.411
# Method:                 Least Squares   F-statistic:                     4490.
# Date:                Thu, 11 Jul 2019   Prob (F-statistic):               0.00
# Time:                        20:27:53   Log-Likelihood:            -8.3740e+05
# No. Observations:               57866   AIC:                         1.675e+06
# Df Residuals:                   57856   BIC:                         1.675e+06
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    1.94e+08   5.08e+06     38.188      0.000    1.84e+08    2.04e+08
# ...

# %%
#remove STORIES AND NUM_UNITS

# %%
result = smf.ols('PRICE ~ ZIPCODE + KITCHENS + ROOMS + BEDRM + BATHRM + HF_BATHRM + FIREPLACES ', data=df).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  PRICE   R-squared:                       0.401
# Model:                            OLS   Adj. R-squared:                  0.401
# Method:                 Least Squares   F-statistic:                     5530.
# Date:                Thu, 11 Jul 2019   Prob (F-statistic):               0.00
# Time:                        20:27:30   Log-Likelihood:            -8.3839e+05
# No. Observations:               57899   AIC:                         1.677e+06
# Df Residuals:                   57891   BIC:                         1.677e+06
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.904e+08   5.12e+06     37.172      0.000     1.8e+08       2e+08
# ...

# %%
result = smf.ols('PRICE ~ KITCHENS + ZIPCODE+ BEDRM + BATHRM + HF_BATHRM ', data=df).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  PRICE   R-squared:                       0.332
# Model:                            OLS   Adj. R-squared:                  0.332
# Method:                 Least Squares   F-statistic:                     5761.
# Date:                Thu, 11 Jul 2019   Prob (F-statistic):               0.00
# Time:                        20:43:00   Log-Likelihood:            -8.4152e+05
# No. Observations:               57899   AIC:                         1.683e+06
# Df Residuals:                   57893   BIC:                         1.683e+06
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   2.267e+08   5.37e+06     42.238      0.000    2.16e+08    2.37e+08
# ...

# %%
# As an investor looking to buy a house, I had thought that the price would be influenced by rooms, zipcode, bathrooms and kitchens. However there is not much correlation 
making me wonder if there is something else that drives up the housing prices besides these.
